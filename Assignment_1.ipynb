# %% [markdown]
# <a href="https://colab.research.google.com/github/MustkeemArsh10/IIT_CV_ASSIGNMENT/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import skimage as io
import cv2


from google.colab.patches import cv2_imshow

# %% [markdown]
# Taking Input of Images

# %%
img_1 = cv2.imread("/content/assignment image.jpeg")
cv2_imshow(img_1)
img_1_gray = cv2.cvtColor(img_1,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_1_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320>
# <PIL.Image.Image image mode=L size=480x320>

# %% [markdown]
# # New Section

# %% [markdown]
# Taking Input

# %%
img_2 = cv2.imread("/content/assignment image2.jpeg")
cv2_imshow(img_2)
img_2_gray = cv2.cvtColor(img_2,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_2_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=639x426>
# <PIL.Image.Image image mode=L size=639x426>

# %% [markdown]
# Applying LBP

# %%
def calculate_lbp(img, x, y):
    center = img[x][y]
    values = []
    for i in range(-1, 2):
        for j in range(-1, 2):
            if i == 0 and j == 0:
                continue
            values.append(1 if img[x + i][y + j] >= center else 0)
    val = 0
    for i in range(len(values)):
      val+=values[i]*2**i

    return val


def apply_lbp(img):
    height, width = img.shape
    lbp_img = np.zeros((height, width), dtype=np.uint8)
    for i in range(1, height - 1):
        for j in range(1, width - 1):
            lbp_img[i, j] = calculate_lbp(img, i, j)
    return lbp_img

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.tight_layout()
ax[0].imshow(lbp_image_1, cmap='gray')
ax[0].set_title('lbp_image_1')
ax[1].imshow(lbp_image_2, cmap='gray')
ax[1].set_title('lbp_image_2')
plt.show()
